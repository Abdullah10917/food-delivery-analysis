# %%
# Food Delivery Data Analysis Hackathon

# %%
import pandas as pd

# %%
This notebook performs data loading, merging, and analysis
on food delivery datasets including orders, users, and restaurants.
